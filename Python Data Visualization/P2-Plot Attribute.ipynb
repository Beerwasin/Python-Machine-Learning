# %%
import matplotlib.pyplot as plt

day=[1,2,3,4,5,6,7]
temp=[20,35,28,30,18,20,18]
plt.plot(day,temp,color='red',linewidth=5) 
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.show()
